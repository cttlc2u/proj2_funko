# %%
from bs4 import BeautifulSoup
import requests
import time, os
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import pickle
import pandas as pd
from collections import defaultdict

# %%
chromedriver = "/Applications/chromedriver"
os.environ["webdriver.chrome.driver"] = chromedriver

# %%
with open('combined_links_df.pickle', 'rb') as read_links:
    links_df = pickle.load(read_links)

# %%
with open('brandseries.pickle', 'rb') as read_brandseries:
    bsp = pickle.load(read_brandseries)

# %%
with open('ppg.pickle', 'rb') as read_details:
    ppg = pickle.load(read_details)

# %%
links_df.set_index('Link',drop=False,inplace=True,verify_integrity=True)

# %%
links_df.head()
# Out:
#                                                       Name  \
# Link
# 12th-man                             12th Man Freddy Funko
# 1950-s-elvis                                  1950's Elvis
# 1950-s-elvis-metallic-gold    1950's Elvis (Metallic Gold)
# 1970-charger-w-dom-toretto  1970 Charger w/Dom Toretto #17
# 1970-s-elvis                                  1970's Elvis
#
#                                                   Link
# Link
# 12th-man                                      12th-man
# 1950-s-elvis                              1950-s-elvis
# 1950-s-elvis-metallic-gold  1950-s-elvis-metallic-gold
# 1970-charger-w-dom-toretto  1970-charger-w-dom-toretto
# 1970-s-elvis                              1970-s-elvis

# %%
bsp
# Out:
# defaultdict(str,
#             {'12th-man': ['Funko Pop Freddy Funko 12th Man Football ECCC 2016 Limited 250pcs Pop Stack',
#               'Pop! Funko: 12th Man Freddy Funko - 2016 ECCC 250 pcs',
#               'Funko Pop Freddy Funko 12th Man Football ECCC 2016 Limited 250pcs Pop Stack',
#               'Funko Pop Freddy Funko 12th Man Football ECCC 2016 Limited 250pcs Pop Stack',
#               'Funko Pop Freddy Funko 12th Man Football ECCC 2016 Limited 250pcs Pop Stack',
#               'Funko',
#               'Freddy Funko',
#               'Pop! Vinyl',
#               'Pop! Funko',
#               'Emerald City Comic Con',
#               'Seattle Seahawks',
#               'National Football League (NFL)'],
#              '1950-s-elvis': ["1950's Elvis",
#               "FUNKO POP 1950'S ELVIS #02, EXCELLENT CONDITION WITH POP PROTECTOR",
#               "Elvis Presley Funko Pop 02 1950's",
#               'Funko Pop Rocks 1950s Elvis Presley',
# ...

# %%
links_df['brand_series'] = links_df['Link'].map(bsp)

# %%
scrape = pd.DataFrame.from_dict(ppg, orient='index',columns=['Estimated_Value','Category_Names','Category_Values','Production_Status'])

# %%
for i in scrape['Category_Values'][:10]:
    print(i)
# Out:
# []
# ['From: 2011', 'Plastic', 'Male', 'Black, Silver, Blue, Pink', '1', 'No', 'English', '']
# ['Plastic', 'Male', 'Black, Silver, Gold', '1', 'No', 'English', '']
# ['From: 2016', 'Plastic', 'Male', 'Black, White, Cadet Blue', '1', 'No', 'English', '']
# ['Plastic', 'Male', 'Black, White, Red, Gold', '1', 'No', 'English', '']
# ['Plastic', 'Male', 'Black, White, Red, Gold', '1', 'No', 'English', '']
# ['From: 2017', 'Plastic, Plastic -> PVC/Vinyl', '3.75"', 'Male', 'Black, White, Lime Green, Sky Blue', 'Bobblehead', 'Weapons', 'Box', 'No', 'English', '']
# ['From: 2017', 'Plastic, Plastic -> PVC/Vinyl', '3.75"', 'Male', 'Black, White, Lime Green, Sky Blue', 'Bobblehead', 'Weapons', 'Box', 'No', 'English', '']
# ['From: 2016', 'Plastic, Plastic -> PVC/Vinyl', '3.75"', 'Black, Gray, Dark Gray, Bronze, Dark Cyan', 'Bobblehead', 'Base', 'Box', 'No', 'English', '']
# ...

# %%
for i in scrape['Category_Names'][:20]:
    print(i)
# Out:
# []
# ['$1,250.00', '$1,200.00', '$750.00', '$650.00', '$300.00', 'Produced:', 'Material:', 'Gender:', 'Color:', 'Number of Points of Articulation:', 'Blind Packaging?:', 'Package Language:']
# ['$1,530.00', '$1,445.00', '$2,500.00', '$2,199.00', '$1,502.15', 'Material:', 'Production Status:', 'Gender:', 'Color:', 'Number of Points of Articulation:', 'Blind Packaging?:', 'Package Language:']
# ['$107.50', '$99.99', '$99.99', '$60.00', '$99.99', 'Produced:', 'Material:', 'Production Status:', 'Gender:', 'Color:', 'Number of Points of Articulation:', 'Blind Packaging?:', 'Package Language:']
# ['$300.00', '$324.99', '$303.82', '$350.00', '$305.00', 'Material:', 'Gender:', 'Color:', 'Number of Points of Articulation:', 'Blind Packaging?:', 'Package Language:']
# ['$1,720.00', '$2,099.00', '$2,395.00', '$2,500.00', '$2,700.00', 'Material:', 'Production Status:', 'Gender:', 'Color:', 'Number of Points of Articulation:', 'Blind Packaging?:', 'Package Language:']
# ...

# %%
scrape.loc['12th-man']['Category_Names'] = ['Produced:','# Produced:', 'Material:','Scale:','Gender:','Color:','Number of Points of Articulation:','Packaging:','Blind Packaging?:','Package Language:']

# %%
#Removing stray price values and redundent 'Production Status' text
for link in links_df['Link']:
    scrape.loc[link]['Category_Names'] = [x for x in scrape.loc[link]['Category_Names'] if (x[0]!='$')]
    scrape.loc[link]['Category_Names'] = [x for x in scrape.loc[link]['Category_Names'] if (x!='Production Status:')]

# %%
scrape['Category_Names'][:10]
# Out:
# 12th-man                                                              [Produced:, # Produced:, Material:, Scale:, Ge...
# 1950-s-elvis                                                          [Produced:, Material:, Gender:, Color:, Number...
# 1950-s-elvis-metallic-gold                                            [Material:, Gender:, Color:, Number of Points ...
# 1970-charger-w-dom-toretto                                            [Produced:, Material:, Gender:, Color:, Number...
# 1970-s-elvis                                                          [Material:, Gender:, Color:, Number of Points ...
# 1970-s-elvis-glow-in-the-dark-479dfff4-e35a-41ac-a66c-20b80117df2c    [Material:, Gender:, Color:, Number of Points ...
# 442nd-clone-trooper-celebration                                       [Produced:, Material:, Scale:, Gender:, Color:...
# 442nd-clone-trooper                                                   [Produced:, Material:, Scale:, Gender:, Color:...
# ...

# %%
#Saving names of POPs without an estimated value
missing_prices = scrape[scrape['Estimated_Value'].isnull()].index

# %%
price_check = defaultdict(str)
db = 'https://www.hobbydb.com/marketplaces/poppriceguide/catalog_items/'
driver = webdriver.Chrome(chromedriver)
for i in missing_prices:
    url = db + i
    driver.get(url)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    price = soup.find('div', class_='value ng-binding')
    if price:
        price = price.text.strip()
    price_check[i] = price
    time.sleep(4)

# %%
print(price_check)

# %%
#with open('missing_est_values.pickle', 'wb') as missing_estimated_values_pickle:
    #pickle.dump(price_check, missing_estimated_values_pickle)

# %%
#After rescraping, some items did not have an est. value, but captured other, missing ones.
with open('missing_est_values.pickle','rb') as read_missing_values:
    price_check = pickle.load(read_missing_values)

# %%
scrape[scrape['Estimated_Value'].isnull()]

# %%
for i in missing_prices:
    scrape.loc[i]['Estimated_Value'] = price_check[i]

# %%
scrape[scrape['Estimated_Value'].isnull()]

# %%
#Removing empty, last field that some had for data updating and source users
for i in links_df['Link']:
    scrape.loc[i]['Category_Values'] = [value for value in scrape.loc[i]['Category_Values'] if value]

# %%
uneven_categories = []
for i in links_df['Link']:
    if len(scrape.loc[i]['Category_Names'])!=len(scrape.loc[i]['Category_Values']):
        uneven_categories.append(i)

# %%
for i in uneven_categories:
    print(scrape.loc[i][['Category_Names','Category_Values']])
# Out:
# Category_Names     [Produced:, Depicts:, Materials:, Color:, Feat...
# Category_Values    [From: 2017, Plastic, Plastic -> PVC/Vinyl, Gr...
# Name: annie-leonhart-38399b18-3665-4ce8-949e-a258e1b7197a, dtype: object
# Category_Names     [Produced:, Depicts:, Materials:, Color:, Feat...
# Category_Values    [From: January 2018, Metal, White, Yellow, Lig...
# Name: bananya-d57b956c-717e-4411-8b7f-18a7289026b7, dtype: object
# Category_Names     [Produced:, Depicts:, Materials:, Color:, Feat...
# Category_Values    [From: January 2018, Metal, White, Yellow, Lig...
# Name: bananyako-e232a29e-21e1-4752-a914-751ce4ab4ba9, dtype: object
# Category_Names     [Produced:, Depicts:, Materials:, Color:, Feat...
# Category_Values    [From: January 2018, Metal, Black, Yellow, Lig...
# Name: bananya-72b740a2-756d-4901-87fc-4adacb35a502, dtype: object
# Category_Names     [Produced:, Depicts:, Materials:, Color:, Shap...
# Category_Values    [From: January 2018, Plastic, Plastic -> PVC/V...
# ...

# %%
db = 'https://www.hobbydb.com/marketplaces/poppriceguide/catalog_items/'
driver = webdriver.Chrome(chromedriver)
for i in uneven_categories:
    url = db + i
    driver.get(url)
    time.sleep(3)

# %%
scrape.head()

# %%
links_df.shape
# Out:
# (11487, 3)

# %%
scrape.shape
# Out:
# (11487, 4)

# %%
ppg_df = pd.concat([links_df,scrape],axis=1)

# %%
ppg_df.head(10)
# Out:
#                                                                                          Name  \
# 12th-man                                                                12th Man Freddy Funko
# 1950-s-elvis                                                                     1950's Elvis
# 1950-s-elvis-metallic-gold                                       1950's Elvis (Metallic Gold)
# 1970-charger-w-dom-toretto                                     1970 Charger w/Dom Toretto #17
# 1970-s-elvis                                                                     1970's Elvis
# 1970-s-elvis-glow-in-the-dark-479dfff4-e35a-41a...            1970's Elvis (Glow in the Dark)
# 442nd-clone-trooper-celebration                             442nd Clone Trooper [Celebration]
# 442nd-clone-trooper                                 442nd Clone Trooper [Galactic Convention]
# 4-lom-58f0e626-d30e-4e19-aac8-e75f0dde306b                                4-LOM [Celebration]
# ...

# %%
ppg_df['Category_Values'][:5]

# %%
for i in ppg_df['Link']:
    if len(ppg_df.loc[i]['Category_Names'])!=len(ppg_df.loc[i]['Category_Values']):
        print(ppg_df.loc[i]['Link'])

# %%
ppg_df.shape
# Out:
# (11487, 7)

# %%
ppg_df.drop(uneven_categories, inplace=True)

# %%
ppg_df.shape
# Out:
# (11464, 7)

# %%
ppg_df.head(10)

# %%
ppg_df['Category_Values'][6]
# Out:
# ['From: 2017',
#  'Plastic, Plastic -> PVC/Vinyl',
#  '3.75"',
#  'Male',
#  'Black, White, Lime Green, Sky Blue',
#  'Bobblehead',
#  'Weapons',
#  'Box',
#  'No',
#  'English']

# %%
ppg_df.loc['12th-man']['Category_Names'] = ['Produced:','# Produced:', 'Material:','Scale:','Gender:','Color:','Number of Points of Articulation:','Packaging:','Blind Packaging?:','Package Language:']

# %%
ppg_df.loc['12th-man']['Category_Values'] = ['From: 2016', 250, 'Plastic', '3.75"', 'Male', 'Silver, Dark Orange, Lime, Navy', '1', 'Box', 'No', 'English']

# %%
for idx in ppg_df['Link'][:1]:
    columns = ppg_df.loc[idx]['Category_Names']
    link_dict = {idx:ppg_df.loc[idx]['Category_Values']}
    expdf = pd.DataFrame.from_dict(link_dict,orient='index',columns=columns)

# %%
for idx in ppg_df['Link'][1:]:
    columns = ppg_df.loc[idx]['Category_Names']
    link_dict = {idx:ppg_df.loc[idx]['Category_Values']}
    expdf = expdf.append(pd.DataFrame.from_dict(link_dict,orient='index',columns=columns))

# %%
cat_columns = expdf

# %%
cat_columns.shape
# Out:
# (11464, 41)

# %%
cat_columns.head()
# Out:
#                              Produced: # Produced: Material: Scale: Gender:  \
# 12th-man                    From: 2016       250.0   Plastic  3.75"    Male
# 1950-s-elvis                From: 2011         NaN   Plastic    NaN    Male
# 1950-s-elvis-metallic-gold         NaN         NaN   Plastic    NaN    Male
# 1970-charger-w-dom-toretto  From: 2016         NaN   Plastic    NaN    Male
# 1970-s-elvis                       NaN         NaN   Plastic    NaN    Male
#
#                                                      Color:  \
# 12th-man                    Silver, Dark Orange, Lime, Navy
# 1950-s-elvis                      Black, Silver, Blue, Pink
# 1950-s-elvis-metallic-gold              Black, Silver, Gold
# 1970-charger-w-dom-toretto         Black, White, Cadet Blue
# 1970-s-elvis                        Black, White, Red, Gold
#
#                            Number of Points of Articulation: Packaging:  \
# ...

# %%
expdf = pd.concat([ppg_df, cat_columns],axis=1)

# %%
expdf.shape
# Out:
# (11464, 48)

# %%
expdf.head()
# Out:
#                                                       Name  \
# 12th-man                             12th Man Freddy Funko
# 1950-s-elvis                                  1950's Elvis
# 1950-s-elvis-metallic-gold    1950's Elvis (Metallic Gold)
# 1970-charger-w-dom-toretto  1970 Charger w/Dom Toretto #17
# 1970-s-elvis                                  1970's Elvis
#
#                                                   Link  \
# 12th-man                                      12th-man
# 1950-s-elvis                              1950-s-elvis
# 1950-s-elvis-metallic-gold  1950-s-elvis-metallic-gold
# 1970-charger-w-dom-toretto  1970-charger-w-dom-toretto
# 1970-s-elvis                              1970-s-elvis
#
#                                                                  brand_series  \
# 12th-man                    [Funko Pop Freddy Funko 12th Man Football ECCC...
# 1950-s-elvis                [1950's Elvis, FUNKO POP 1950'S ELVIS #02, EXC...
# ...

# %%
#Removing column name, 'Production Status', from values
for link in expdf['Link']:
    expdf.loc[link]['Production_Status'] = [x for x in expdf.loc[link]['Production_Status'] if (x!='Production Status:')]

# %%
expdf.head()
# Out:
#                                                       Name  \
# 12th-man                             12th Man Freddy Funko
# 1950-s-elvis                                  1950's Elvis
# 1950-s-elvis-metallic-gold    1950's Elvis (Metallic Gold)
# 1970-charger-w-dom-toretto  1970 Charger w/Dom Toretto #17
# 1970-s-elvis                                  1970's Elvis
#
#                                                   Link  \
# 12th-man                                      12th-man
# 1950-s-elvis                              1950-s-elvis
# 1950-s-elvis-metallic-gold  1950-s-elvis-metallic-gold
# 1970-charger-w-dom-toretto  1970-charger-w-dom-toretto
# 1970-s-elvis                              1970-s-elvis
#
#                                                                  brand_series  \
# 12th-man                    [Funko Pop Freddy Funko 12th Man Football ECCC...
# 1950-s-elvis                [1950's Elvis, FUNKO POP 1950'S ELVIS #02, EXC...
# ...

# %%
expdf.count().sort_values(ascending=False)
# Out:
# Name                                 11464
# brand_series                         11464
# Category_Names                       11464
# Category_Values                      11464
# Production_Status                    11464
# Link                                 11464
# Material:                            11405
# Color:                               11397
# Blind Packaging?:                    11355
# Package Language:                    11236
# Produced:                            11089
# Estimated_Value                      10994
# Gender:                              10701
# Packaging:                            8059
# Number of Points of Articulation:     7873
# Scale:                                6754
# Features:                             1959
# Accessories:                          1450
# Figure Height:                        1353
# Box Depth:                             987
# Box Width:                             985
# Box Height:                            978
# ...

# %%
expdf['Packaging:'].value_counts()
# Out:
# Box           7620
# Clamshell        2
# Bag              2
# Multi-pack       1
# Loose            1
# Name: Packaging:, dtype: int64

# %%
expdf.dropna(subset=['Estimated_Value'],inplace=True)

# %%
expdf.shape
# Out:
# (10994, 48)

# %%
pd.get_dummies(expdf['brand_series'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/arrays/categorical.py in __init__(self, values, categories, ordered, dtype, fastpath)
#     339             try:
# --> 340                 codes, categories = factorize(values, sort=True)
#     341             except TypeError as err:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/algorithms.py in factorize(values, sort, na_sentinel, size_hint)
#     722         codes, uniques = factorize_array(
# --> 723             values, na_sentinel=na_sentinel, size_hint=size_hint, na_value=na_value
#     724         )
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/algorithms.py in factorize_array(values, na_sentinel, size_hint, na_value, mask)
#     528     uniques, codes = table.factorize(
# --> 529         values, na_sentinel=na_sentinel, na_value=na_value, mask=mask
# ...
