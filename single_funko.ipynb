# %%
from bs4 import BeautifulSoup
import requests
import time, os
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import pandas as pd

# %%
chromedriver = "/Applications/chromedriver" # path to the chromedriver executable
os.environ["webdriver.chrome.driver"] = chromedriver

# %%
url = 'https://www.hobbydb.com/marketplaces/poppriceguide/catalog_items/12th-man'

# %%
driver = webdriver.Chrome(chromedriver)
driver.get(url)

# %%
driver.page_source[:1000]
# Out:
# '<html lang="en" class="fontawesome-i2svg-active fontawesome-i2svg-complete"><head><style type="text/css">svg:not(:root).svg-inline--fa{overflow:visible}.svg-inline--fa{display:inline-block;font-size:inherit;height:1em;overflow:visible;vertical-align:-.125em}.svg-inline--fa.fa-lg{vertical-align:-.225em}.svg-inline--fa.fa-w-1{width:.0625em}.svg-inline--fa.fa-w-2{width:.125em}.svg-inline--fa.fa-w-3{width:.1875em}.svg-inline--fa.fa-w-4{width:.25em}.svg-inline--fa.fa-w-5{width:.3125em}.svg-inline--fa.fa-w-6{width:.375em}.svg-inline--fa.fa-w-7{width:.4375em}.svg-inline--fa.fa-w-8{width:.5em}.svg-inline--fa.fa-w-9{width:.5625em}.svg-inline--fa.fa-w-10{width:.625em}.svg-inline--fa.fa-w-11{width:.6875em}.svg-inline--fa.fa-w-12{width:.75em}.svg-inline--fa.fa-w-13{width:.8125em}.svg-inline--fa.fa-w-14{width:.875em}.svg-inline--fa.fa-w-15{width:.9375em}.svg-inline--fa.fa-w-16{width:1em}.svg-inline--fa.fa-w-17{width:1.0625em}.svg-inline--fa.fa-w-18{width:1.125em}.svg-inline--fa.fa-w-19{width:1.1
# ...

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
#urlreq = requests.get(url)
#urlreq.status_code

# %%
#urlpage = urlreq.text
#soup = BeautifulSoup(urlpage, 'lxml')
#print(soup.prettify())

# %%
print(soup.prettify())
# Out:
# <html class="fontawesome-i2svg-active fontawesome-i2svg-complete" lang="en">
#  <head>
#   <style type="text/css">
# ...

# %%
soup.find_all('item-price-guide')
# Out:
# [<item-price-guide class="ng-isolate-scope" id="322482"><!-- ngIf: data.showGuide --><div class="ng-scope" ng-if="data.showGuide">
#  <h3>Price Guide</h3>
#  <hr/>
#  <div class="row item-price-guide">
#  <div class="col-md-12">
#  <!-- ngIf: data.loading -->
#  <!-- ngIf: data.errors -->
#  <div class="container-fluid">
#  <div class="row">
#  <!-- ngIf: data.guide.attributes.estimated_value --><div class="col-md-12 pricing-block ng-scope" ng-if="data.guide.attributes.estimated_value">
#  <div class="estimated-value">
#  <div class="value ng-binding">
#                  $270.00
#                </div>
#  <div class="timestamp">
#  <timestamp class="ng-isolate-scope" timestamp="11 January 2021 10pm EST"><span class="timestamp">
#  <span class="tooltip-container">
#  <span class="timestamp-icon">
# ...

# %%
soup.find_all('div', class_='estimated-value')
# Out:
# [<div class="estimated-value">
#  <div class="value ng-binding">
#                  $270.00
#                </div>
#  <div class="timestamp">
#  <timestamp class="ng-isolate-scope" timestamp="11 January 2021 10pm EST"><span class="timestamp">
#  <span class="tooltip-container">
#  <span class="timestamp-icon">
#  <svg aria-hidden="true" class="svg-inline--fa fa-clock fa-w-16" data-fa-i2svg="" data-icon="clock" data-prefix="fas" focusable="false" role="img" viewbox="0 0 512 512" xmlns="http://www.w3.org/2000/svg"><path d="M256,8C119,8,8,119,8,256S119,504,256,504,504,393,504,256,393,8,256,8Zm92.49,313h0l-20,25a16,16,0,0,1-22.49,2.5h0l-67-49.72a40,40,0,0,1-15-31.23V112a16,16,0,0,1,16-16h32a16,16,0,0,1,16,16V256l58,42.5A16,16,0,0,1,348.49,321Z" fill="currentColor"></path></svg><!-- <i class="fas fa-clock"></i> -->
#  </span>
#  <span class="tooltip-text-right ng-binding">
#        Last calculated 11 January 2021 10pm EST
#      </span>
#  </span>
#  </span></timestamp>
#  </div>
# ...

# %%
soup.find_all('div', class_='value ng-binding')
# Out:
# [<div class="value ng-binding">
#                  $270.00
#                </div>]

# %%
soup.find('div', class_='value ng-binding').text.strip()
# Out:
# '$280.00'

# %%
soup.find('Production Status')

# %%
soup.find_all('div', class_='row')
# Out:
# [<div class="row">
#  <div class="col-md-12 marketplace-header-image">
#  <img alt="Pop Price Guide" src="https://www.hobbydb.com/processed_uploads/market/cover_image/2/1594055725-9313-1066/ppg_markeplace_header_Tavola_disegno_1_xxlarge.png" title="Pop Price Guide"/>
#  </div>
#  </div>,
#  <div class="row">
#  <div class="col-md-8 col-md-offset-2">
#  </div>
#  <local-storage-flashes class="ng-isolate-scope"><div>
#  <div class="alert alert-success alert-dismissable ng-binding ng-hide" ng-bind="data.success" ng-show="data.success"></div>
#  </div></local-storage-flashes>
#  </div>,
#  <div class="row">
#  <div class="ad-row">
#  <div data-google-query-id="CLiE7MPgl-4CFeIAaAgd0wAC8A" id="HDB_D_detail_top" style="">
# ...

# %%
prod_status = soup.find_all('b', class_='')
print(prod_status)
# Out:
# [<b>Production Status: </b>]

# %%
prod_status = soup.find_all('b', class_='')
if prod_status:
    for i in prod_status:
        print(i.text.strip())
    exclusive = soup.find_all('li')
    for i in exclusive:
        print(i.text.strip())
# Out:
# Production Status:
# Exclusive

# %%
fields = soup.find_all('b', class_='ng-binding')

# %%
for i in fields:
    print(i.text)
    
#Start at Produced
# Out:
#                 $300.00
#
#
#                 $230.00
#
#
#                 $255.00
#
#
#                 $204.50
#
#
#                 $399.99
#
# Produced:
# # Produced:
# Material:
# Scale:
# Gender:
# Color:
# Number of Points of Articulation:
# Packaging:
# Blind Packaging?:
# Package Language:

# %%
fields_list = []
for i in fields:
    fields_list.append(i.text.strip())

# %%
fields_list
# Out:
# ['$300.00',
#  '$230.00',
#  '$255.00',
#  '$204.50',
#  '$399.99',
#  'Produced:',
#  '# Produced:',
#  'Material:',
#  'Scale:',
#  'Gender:',
#  'Color:',
#  'Number of Points of Articulation:',
#  'Packaging:',
#  'Blind Packaging?:',
#  'Package Language:']

# %%
soup.find_all('span', class_='ng-binding')
# Out:
# [<span class="query ng-binding"></span>,
#  <span class="query ng-binding"></span>,
#  <span class="query ng-binding"></span>,
#  <span class="query ng-binding"></span>,
#  <span class="query ng-binding"></span>,
#  <span class="query ng-binding"></span>,
#  <span class="tooltip-text-right ng-binding">
#        Last calculated 11 January 2021 10pm EST
#      </span>,
#  <span class="ng-binding" ng-hide="display.url">
#                From: 2016<span class="ng-hide" ng-hide="$last || display.estimable">, </span>
#  </span>,
#  <span class="ng-binding ng-hide" ng-show="display.estimable">
#                ()<span class="ng-hide" ng-hide="$last">, </span>
#  </span>,
#  <span class="ng-binding" ng-hide="display.url">
#                250<span class="ng-hide" ng-hide="$last || display.estimable">, </span>
#  </span>,
#  <span class="ng-binding ng-hide" ng-show="display.estimable">
#                ()<span class="ng-hide" ng-hide="$last">, </span>
#  </span>,
# ...

# %%
soup.find_all('a class="ng-binding" href=""')
# Out:
# []

# %%
details = soup.find_all('a', class_='ng-binding',href="")

# %%
exclusive = soup.find_all('li')

# %%
exclusive = soup.find_all('li')
for i in exclusive:
    print(i.text.strip())
# Out:
# Exclusive

# %%
print(exclusive.text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-112-b464d0af9ff2> in <module>
# ----> 1 print(exclusive.text)
#
# ~/anaconda3/lib/python3.7/site-packages/bs4/element.py in __getattr__(self, key)
#    2172         """Raise a helpful exception to explain a common code fix."""
#    2173         raise AttributeError(
# -> 2174             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2175         )
#
# AttributeError: ResultSet object has no attribute 'text'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
for i in details:
    print(i.text)
    
#Start at From (assuming all start with Produced)
# Out:
# From: 2016
# 250
# Plastic
# 3.75"
# Male
# Silver, Dark Orange, Lime, Navy
# 1
# Box
# No
# English

# %%
soup.find_all('h3')
# Out:
# [<h3>Statistics</h3>,
#  <h3>Price Guide</h3>,
#  <h3 class="ng-binding">Get Accessories!</h3>,
#  <h3 class="title">
#          Price Points
#        </h3>,
#  <h3>Related Subjects</h3>,
#  <h3>Production Details</h3>,
#  <h3 class="ng-binding">Characteristics</h3>,
#  <h3>Reference Numbers</h3>,
#  <h3>Metadata</h3>]

# %%
soup.find_all('div', class_='ng-binding ng-scope')
# Out:
# [<div class="ng-binding ng-scope" ng-if="string.length &lt;= max">
#    Funko Pop Freddy Funko 12th Man Football ECCC 2016 Limited 250pcs Pop Stack
#  </div>,
#  <div class="ng-binding ng-scope" ng-if="string.length &lt;= max">
#    Pop! Funko: 12th Man Freddy Funko - 2016 ECCC 250 pcs
#  </div>,
#  <div class="ng-binding ng-scope" ng-if="string.length &lt;= max">
#    Funko Pop Freddy Funko 12th Man Football ECCC 2016 Limited 250pcs Pop Stack
#  </div>,
#  <div class="ng-binding ng-scope" ng-if="string.length &lt;= max">
#    Funko Pop Freddy Funko 12th Man Football ECCC 2016 Limited 250pcs Pop Stack
#  </div>,
#  <div class="ng-binding ng-scope" ng-if="string.length &lt;= max">
#    Funko Pop Freddy Funko 12th Man Football ECCC 2016 Limited 250pcs Pop Stack
#  </div>,
#  <div class="ng-binding ng-scope" ng-if="string.length &lt;= max">
#    Funko
#  </div>,
#  <div class="ng-binding ng-scope" ng-if="string.length &lt;= max">
#    Freddy Funko
#  </div>,
# ...

# %%
fandoms = soup.find_all('div', class_='ng-binding ng-scope')

# %%
for i in fandoms:
    print(i.text)
    
#Start at Funko
# Out:
#   Funko Pop Freddy Funko 12th Man Football ECCC 2016 Limited 250pcs Pop Stack
#
#
#   Pop! Funko: 12th Man Freddy Funko - 2016 ECCC 250 pcs
#
#
#   Funko Pop Freddy Funko 12th Man Football ECCC 2016 Limited 250pcs Pop Stack
#
#
#   Funko Pop Freddy Funko 12th Man Football ECCC 2016 Limited 250pcs Pop Stack
#
#
#   Funko Pop Freddy Funko 12th Man Football ECCC 2016 Limited 250pcs Pop Stack
#
#
#   Funko
#
#
#   Freddy Funko
#
#
#   Pop! Vinyl
#
#
#   Pop! Funko
#
#
#   Emerald City Comic Con
#
#
#   Seattle Seahawks
#
#
#   National Football League (NFL)

# %%
soup.find('truncate')
# Out:
# <truncate class="ng-isolate-scope" max="120" string="Funko Pop Freddy Funko 12th Man Football ECCC 2016 Limited 250pcs Pop Stack"><!-- ngIf: string.length <= max --><div class="ng-binding ng-scope" ng-if="string.length &lt;= max">
#   Funko Pop Freddy Funko 12th Man Football ECCC 2016 Limited 250pcs Pop Stack
# </div><!-- end ngIf: string.length <= max -->
# <!-- ngIf: string.length > max --></truncate>

# %%
soup.find_all('a class="ng-binding" ng-href=""')
