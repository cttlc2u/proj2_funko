# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd
import pickle

# %%
with open('HTMLs/ppg_0.txt') as f:
        batchsoup = BeautifulSoup(f.read())

# %%
batchsoup
# Out:
# <html class="fontawesome-i2svg-active fontawesome-i2svg-complete" lang="en"><head><style type="text/css">svg:not(:root).svg-inline--fa{overflow:visible}.svg-inline--fa{display:inline-block;font-size:inherit;height:1em;overflow:visible;vertical-align:-.125em}.svg-inline--fa.fa-lg{vertical-align:-.225em}.svg-inline--fa.fa-w-1{width:.0625em}.svg-inline--fa.fa-w-2{width:.125em}.svg-inline--fa.fa-w-3{width:.1875em}.svg-inline--fa.fa-w-4{width:.25em}.svg-inline--fa.fa-w-5{width:.3125em}.svg-inline--fa.fa-w-6{width:.375em}.svg-inline--fa.fa-w-7{width:.4375em}.svg-inline--fa.fa-w-8{width:.5em}.svg-inline--fa.fa-w-9{width:.5625em}.svg-inline--fa.fa-w-10{width:.625em}.svg-inline--fa.fa-w-11{width:.6875em}.svg-inline--fa.fa-w-12{width:.75em}.svg-inline--fa.fa-w-13{width:.8125em}.svg-inline--fa.fa-w-14{width:.875em}.svg-inline--fa.fa-w-15{width:.9375em}.svg-inline--fa.fa-w-16{width:1em}.svg-inline--fa.fa-w-17{width:1.0625em}.svg-inline--fa.fa-w-18{width:1.125em}.svg-inline--fa.fa-w-19{width:1.18
# ...

# %%
batchsoup.find_all()
# Out:
# [<html class="fontawesome-i2svg-active fontawesome-i2svg-complete" lang="en"><head><style type="text/css">svg:not(:root).svg-inline--fa{overflow:visible}.svg-inline--fa{display:inline-block;font-size:inherit;height:1em;overflow:visible;vertical-align:-.125em}.svg-inline--fa.fa-lg{vertical-align:-.225em}.svg-inline--fa.fa-w-1{width:.0625em}.svg-inline--fa.fa-w-2{width:.125em}.svg-inline--fa.fa-w-3{width:.1875em}.svg-inline--fa.fa-w-4{width:.25em}.svg-inline--fa.fa-w-5{width:.3125em}.svg-inline--fa.fa-w-6{width:.375em}.svg-inline--fa.fa-w-7{width:.4375em}.svg-inline--fa.fa-w-8{width:.5em}.svg-inline--fa.fa-w-9{width:.5625em}.svg-inline--fa.fa-w-10{width:.625em}.svg-inline--fa.fa-w-11{width:.6875em}.svg-inline--fa.fa-w-12{width:.75em}.svg-inline--fa.fa-w-13{width:.8125em}.svg-inline--fa.fa-w-14{width:.875em}.svg-inline--fa.fa-w-15{width:.9375em}.svg-inline--fa.fa-w-16{width:1em}.svg-inline--fa.fa-w-17{width:1.0625em}.svg-inline--fa.fa-w-18{width:1.125em}.svg-inline--fa.fa-w-19{width:1.1
# ...

# %%
batchsoup.find('h1').string.strip()
# Out:
# 'Freddy Funko'

# %%
#Alternative name?
batchsoup.find(string=re.compile("Alternative Name:")).string.strip()
# Out:
# 'Alternative Name: 12th Man Freddy Funko'

# %%
batchsoup.find('div', class_='value ng-binding').string.strip()
# Out:
# '$310.00'

# %%
batchsoup.find_all('td',class_="days ng-binding")
# Out:
# [<td class="days ng-binding">
#                      30 days
#                    </td>,
#  <td class="days ng-binding">
#                      90 days
#                    </td>,
#  <td class="days ng-binding">
#                      180 days
#                    </td>,
#  <td class="days ng-binding">
#                      1 year
#                    </td>]

# %%
#Avg, low, median, high
#Is it better to iterate straight through or by 4
batchsoup.find_all(lambda tag: tag.name == 'td' and tag.get('class') == ['ng-binding'])
# Out:
# [<td class="ng-binding">$315.00</td>,
#  <td class="ng-binding">$315.00</td>,
#  <td class="ng-binding">$315.00</td>,
#  <td class="ng-binding">$315.00</td>,
#  <td class="ng-binding">$300.00</td>,
#  <td class="ng-binding">$300.00</td>,
#  <td class="ng-binding">$300.00</td>,
#  <td class="ng-binding">$300.00</td>,
#  <td class="ng-binding">$287.90</td>,
#  <td class="ng-binding">$204.50</td>,
#  <td class="ng-binding">$255.00</td>,
#  <td class="ng-binding">$399.99</td>,
#  <td class="ng-binding">$314.14</td>,
#  <td class="ng-binding">$289.99</td>,
#  <td class="ng-binding">$325.00</td>,
#  <td class="ng-binding">$325.00</td>]

# %%
batchsoup.find_all('td',class_="ng-binding")
# Out:
# [<td class="days ng-binding">
#                      30 days
#                    </td>,
#  <td class="sales-number ng-binding">
#                      1
#                    </td>,
#  <td class="ng-binding">$315.00</td>,
#  <td class="ng-binding">$315.00</td>,
#  <td class="ng-binding">$315.00</td>,
#  <td class="ng-binding">$315.00</td>,
#  <td class="days ng-binding">
#                      90 days
#                    </td>,
#  <td class="sales-number ng-binding">
#                      1
#                    </td>,
#  <td class="ng-binding">$300.00</td>,
#  <td class="ng-binding">$300.00</td>,
#  <td class="ng-binding">$300.00</td>,
#  <td class="ng-binding">$300.00</td>,
#  <td class="days ng-binding">
#                      180 days
#                    </td>,
#  <td class="sales-number ng-binding">
#                      5
#                    </td>,
#  <td class="ng-binding">$287.90</td>,
#  <td class="ng-binding">$204.50</td>,
#  <td class="ng-binding">$255.00</td>,
# ...

# %%
#loop and create strings
#make list
#everything Funko forward
for i in batchsoup.find_all('div', class_='ng-binding ng-scope'):
    print(i.string.strip())
# Out:
# FUNKO POP FREDDY FUNKO 12th Man Eccc 2016 Only 250 Made
# Funko Pop Freddy Funko 12th Man Football ECCC 2016 Limited 250pcs Pop Stack
# Pop! Funko: 12th Man Freddy Funko - 2016 ECCC 250 pcs
# Funko Pop Freddy Funko 12th Man Football ECCC 2016 Limited 250pcs Pop Stack
# Funko Pop Freddy Funko 12th Man Football ECCC 2016 Limited 250pcs Pop Stack
# Funko
# Freddy Funko
# Pop! Vinyl
# Pop! Funko
# Emerald City Comic Con
# Seattle Seahawks
# National Football League (NFL)

# %%
#account for blank at end
for i in batchsoup.find_all('a', class_='ng-binding',href=""):
    print(i.string.strip())
# Out:
# 250
# Plastic
# 3.75"
# Male
# Silver, Dark Orange, Lime, Navy
# 1
# Box
# No
# English

# %%
batchsoup.find_all('b', class_='')
# Out:
# [<b>Released:</b>, <b>Production Status: </b>]

# %%
batchsoup.find_all('b')
# Out:
# [<b class="ng-binding">
#                  $315.00
#                </b>,
#  <b class="ng-binding">
#                  $300.00
#                </b>,
#  <b class="ng-binding">
#                  $230.00
#                </b>,
#  <b class="ng-binding">
#                  $255.00
#                </b>,
#  <b class="ng-binding">
#                  $204.50
#                </b>,
#  <b>Released:</b>,
#  <b class="ng-binding"># Produced:</b>,
#  <b class="ng-binding">Material:</b>,
#  <b>Production Status: </b>,
#  <b class="ng-binding">Scale:</b>,
#  <b class="ng-binding">Gender:</b>,
#  <b class="ng-binding">Color:</b>,
#  <b class="ng-binding">Number of Points of Articulation:</b>,
#  <b class="ng-binding">Packaging:</b>,
#  <b class="ng-binding">Blind Packaging?:</b>,
#  <b class="ng-binding">Package Language:</b>]

# %%
#find a way to get only year
batchsoup.find_all('div', class_='ng-binding')
# Out:
# [<div class="ng-binding" ng-hide="data.q">
#  <svg aria-hidden="true" class="svg-inline--fa fa-shopping-cart fa-w-18" data-fa-i2svg="" data-icon="shopping-cart" data-prefix="fas" focusable="false" role="img" viewbox="0 0 576 512" xmlns="http://www.w3.org/2000/svg"><path d="M528.12 301.319l47.273-208C578.806 78.301 567.391 64 551.99 64H159.208l-9.166-44.81C147.758 8.021 137.93 0 126.529 0H24C10.745 0 0 10.745 0 24v16c0 13.255 10.745 24 24 24h69.883l70.248 343.435C147.325 417.1 136 435.222 136 456c0 30.928 25.072 56 56 56s56-25.072 56-56c0-15.674-6.447-29.835-16.824-40h209.647C430.447 426.165 424 440.326 424 456c0 30.928 25.072 56 56 56s56-25.072 56-56c0-22.172-12.888-41.332-31.579-50.405l5.517-24.276c3.413-15.018-8.002-29.319-23.403-29.319H218.117l-6.545-32h293.145c11.206 0 20.92-7.754 23.403-18.681z" fill="currentColor"></path></svg><!-- <i class="fas fa-shopping-cart"></i> --> Marketplace
#        </div>,
#  <div class="ng-binding ng-hide" ng-show="data.q">
# ...

# %%
#defaultdict
#loop through files
#make the soup
#name
#alternative name
